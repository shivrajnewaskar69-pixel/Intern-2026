# %% [markdown]
# # Decision making and looping

# %%
num= int(input("enter the number"))
if num > 5:
   print("yes")
# Out:
# enter the number 10
# yes

# %%
num = int(input("enter the number"))
if num>5:
    print("yes")
else:
    print("no")
# Out:
# enter the number 3
# no

# %%
num=int(input("enter the number"))
if num>0:
    print("positive")
elif num==0:
    print("zero")
else:
    print("negative")
# Out:
# enter the number 0
# zero

# %%
num=int(input("enter the number"))
if num%2==0:
    print("even")
else: 
    print("odd")
# Out:
# enter the number 3
# odd

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True+True+False
# Out:
# 2

# %%
a=1
if a:
    print('exists')
# Out:
# exists

# %%
# check the number is inn between 50 and 100 or not(use nested if)

# %%
num=int(input("enter the number"))
if num>50 and num<100:
    print("between")
else:
    print("not between")
# Out:
# enter the number 101
# not between

# %%
num=int(input("enter the number"))
if num>50:
    if num<100:
        print("condition satisfied")
    else:
        print("greater than 50 but not less than 100")
else:
    print("number is less than 50")
# Out:
# enter the number 50
# number is less than 50

# %% [markdown]
# #read purchase cost and selling cost fromm user
# #state profit or loss and how much

# %%
purchase= int(input("enter the purchase cost:"))
selling=int(input("enter the selling price:"))
if purchase>selling:
    print("loss",purchase-selling)
else:
    print("profit",selling-purchase)
# Out:
# enter the purchase cost: 1000
# enter the selling price: 300
# loss 700

# %%
year=int(input("enter the year:"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("century leap")
        else:
          print("century but not leap")
    else:
     print("leap")
else:
     print("not leap")
# Out:
# enter the year: 1999
# not leap

# %%
#take 3 number find which one is largedt use nested if

# %%
num1=int(input("enter number:"))
num2=int(input("enter number:"))
num3=int(input("enter number"))
if num1>num2:
           if num1>num3:
               print("num1 is largest")
    
           else:
            print("num3 is largest")
else:
    if num2>num1:
            print("num2 is largest")
    else:
           print("num3 is largest")
# Out:
# enter number: 5
# enter number: 4
# enter number 6
# num3 is largest

# %%
#menu driven

# %%
print("welcome to the simple calculator")
num=int(input("enter the number"))
print("menu=>\n1.Square\n2.Cube\n3.check +ve or -ve")
ch= int(input("select ur choice"))
if ch==1:
    print(num+num)
elif ch==2:
    print(num**3)
elif ch==3:
    if num>0:
        print("positive")
    elif num==0:
        print("zero")
    else:
        print("negative")
else:
    print("ghari jaa!!!!")
# Out:
# welcome to the simple calculator
# enter the number 3
# menu=>
# 1.Square
# 2.Cube
# 3.check +ve or -ve
# select ur choice 343553453438
# ghari jaa!!!!

# %%
print("menu driven")
string=(input("enter the string:"))
print("menu->\n1.uppercase\n2.lowercase\n3.replace")
ch=int(input("select the choice"))
if ch==1:
     print(string.upper())
elif ch==2:
     print(string.lower())
elif ch==3:
     r1=input("which part you want to replace:")
     r2=input("what you want to replace it with")
     new=text.replace(r1,r2)
     print(f"result->{new}")
# Out:
# menu driven
# enter the string: raj
# menu->
# 1.uppercase
# 2.lowercase
# 3.replace
# select the choice 3
# which part you want to replace: 2
# what you want to replace it with
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 12
#      10 r1=input("which part you want to replace:")
#      11 r2=input("what you want to replace it with")
# ---> 12 new=text.replace(r1,r2)
#      13 print(f"result->{new}")
#
# NameError: name 'text' is not defined
