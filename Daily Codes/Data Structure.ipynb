# %% [markdown]
# # Data Structure

# %% [markdown]
# # list

# %%
l1=[23,45,67,89,12]

# %% [markdown]
# # list are hetro and duplicates are allowed

# %%
l1=[23,45,33.33,23,45]

# %%
l1 =[23,45,67,89,'python','java',23,45]
print(l1)
# Out:
# [23, 45, 67, 89, 'python', 'java', 23, 45]

# %% [markdown]
# # list are mutable

# %%
l1=[1]

# %%
l2=[21,23,45,67,89,11]

# %%
l2
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l2[1:4]
# Out:
# [23, 45, 67]

# %%
l2[1:-2]
# Out:
# [23, 45, 67]

# %%
l2[0:6:2]
# Out:
# [21, 45, 89]

# %%
l2[1::2]
# Out:
# [23, 67, 11]

# %%
# reverse the list

# %%
l2[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l2[1:4]=[100,200,300]

# %%
l2
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l3=[12,34,56,23]

# %%
l3
# Out:
# [12, 34, 56, 23]

# %%
del l3[-2]

# %%
l3
# Out:
# [12, 23]

# %%
333 in l3
# Out:
# False

# %%
l3 * 9
# Out:
# [12, 23, 12, 23, 12, 23, 12, 23, 12, 23, 12, 23, 12, 23, 12, 23, 12, 23]

# %%
for i in l3:
      print(i**2,end=' ')
# Out:
# 144 529

# %%
# print odd number in the list

# %%
l4=[21,100,200,300,89,11]

# %%
l4
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
for i in l4:
     if i%2==1:
         print(i,end=' ')
# Out:
# 21 89 11

# %%
new1=[i**2 for i in l4]

# %%
new1
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
names=['Aryan','atharv','sammruddhi','swaraj','Sukanya','shivraj']

# %%
names
# Out:
# ['Aryan', 'atharv', 'sammruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# sammruddhi
# swaraj
# Sukanya
# shivraj

# %%
new=[i for i in names if i.lower().startswith('s')]
new
# Out:
# ['sammruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
max(new1)
# Out:
# 90000

# %%
min(new1)
# Out:
# 121

# %%
sorted(new1)
# Out:
# [121, 441, 7921, 10000, 40000, 90000]

# %%
sorted(new1,reverse=True)
# Out:
# [90000, 40000, 10000, 7921, 441, 121]

# %% [markdown]
# # list method

# %% [markdown]
# # append

# %%
new1.append(2)

# %%
new1
# Out:
# [441, 10000, 40000, 90000, 7921, 121, 2]

# %%
l1=[1,2,3,]
l2=[1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200], [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, [100, 200], 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=566775575
l1
# Out:
# [1, 2, 3, [100, 566775575], [100, 200]]

# %%
l=[1,22,33,44]
l
# Out:
# [1, 22, 33, 44]

# %%
l.insert(1,56)
l
# Out:
# [1, 56, 22, 33, 44]

# %%
l.remove(1)
l
# Out:
# [22, 33, 44]

# %%
l.pop()
# Out:
# 44

# %%
l.pop(1)
# Out:
# 33

# %%
l.index(22)
# Out:
# 0

# %%
l.sort()

# %%
l
# Out:
# [22]

# %%
l=[34,56,12,48,19,10]
l
# Out:
# [34, 56, 12, 48, 19, 10]

# %%
for i in l:
    print(f"{l.index(i)}=>{i}")
# Out:
# 0=>34
# 1=>56
# 2=>12
# 3=>48
# 4=>19
# 5=>10

# %%
for ind,val in enumerate(1):
    print(f"{ind}=>{val}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for ind,val in enumerate(1):
#       2     print(f"{ind}=>{val}")
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# # tuple

# %%
t=(56,78,90,12,56,True,"hello")
t
# Out:
# (56, 78, 90, 12, 56, True, 'hello')

# %%
t[5] #ordered
# Out:
# True

# %%
t [5]=1
t #immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t [5]=1
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(67,)
t1
# Out:
# (67,)

# %%
type(t1)
# Out:
# tuple

# %%
t2=(69)

# %%
type(t2)
# Out:
# int

# %%
t4=7,
t4
# Out:
# (7,)

# %%
type(t4)
# Out:
# tuple

# %%
l1=list(t)
l1
# Out:
# [56, 78, 90, 12, 56, True, 'hello']

# %%
l1[-3]=100
t = tuple(11)
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 l1[-3]=100
# ----> 2 t = tuple(11)
#
# TypeError: 'int' object is not callable

# %%
t5=(67,43,45,32,[65,78],89,100)
t5
# Out:
# (67, 43, 45, 32, [65, 78], 89, 100)

# %%
t5[4][0]=1000
t5
# Out:
# (67, 43, 45, 32, [1000, 78], 89, 100)

# %%
#copying

# %%
l=[34,56,12,48,19,34,10]

# %%
z=l

# %%
z
# Out:
# [34, 56, 12, 48, 19, 34, 10]

# %%
l[0]=1000

# %%
l
# Out:
# [1000, 56, 12, 48, 19, 34, 10]

# %%
z
# Out:
# [1000, 56, 12, 48, 19, 34, 10]

# %%
l=[34,56,12,48,[19,56],34,10]
l
# Out:
# [34, 56, 12, 48, [19, 56], 34, 10]

# %%
z=l.copy()

# %%
z
# Out:
# [34, 56, 12, 48, [19, 56], 34, 10]

# %%
l[0]=1000
l
# Out:
# [1000, 56, 12, 48, [19, 56], 34, 10]

# %%
z
# Out:
# [34, 56, 12, 48, [19, 56], 34, 10]

# %%
l[-3][0]=1000
l
# Out:
# [1000, 56, 12, 48, [1000, 56], 34, 10]

# %%
z
# Out:
# [34, 56, 12, 48, [1000, 56], 34, 10]

# %%
t=(33,44,55,64,66,89)
t
# Out:
# (33, 44, 55, 64, 66, 89)

# %%
max(t)
# Out:
# 89

# %%
min(t)
# Out:
# 33

# %%
sorted(t)
# Out:
# [33, 44, 55, 64, 66, 89]

# %% [markdown]
# # Sets

# %%
s={34,56,123,123,True,False,"hello"} #unordred
s
# Out:
# {123, 34, 56, False, True, 'hello'}

# %%
s.add(57)

# %%
s #mutable
# Out:
# {123, 34, 56, 57, False, True, 'hello'}

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s=set()
type(s)
# Out:
# set

# %% [markdown]
# # Dictionary

# %%
d={1:"one",2:"two",3:"three"}
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
type(d)
# Out:
# dict

# %%
d[1]
# Out:
# 'one'

# %%
d={1:"one",2:"two",3:"three",4:"four"}

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}
